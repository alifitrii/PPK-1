# %% [markdown]
# ## Alif Fitri Auni Miftakhul Jannah
# ## 200601110097
# ## Latihan

# %% [markdown]
# ## No 1

# %%
Buatlah program untuk menginputkan dua buah bilangan bulat, kemudian mencetak salah satu bilangan yang nilainya terbesar!

# %%
print ('Menentukan bilangan terbesar dari dua bilangan bulat')
def pengulangan():
    a=input('Masukkan bilangan pertama: ')
    b=input('Masukkan bilangan kedua: ')
    if a>b:
        print (a, 'terbesar')
    elif b>a:
        print (b, 'terbesar')
        
    print ('')
    print ('====================================================')
    print ('             Sudah Yakin??? (Ya atau Tidak)         ')
    print ('====================================================')
    x=input()
    if x=='Tidak':
        return pengulangan()
    if x=='Ya':
        print('Terima kasih, SEMANGAT:)')
        
pengulangan()
# Out:
# Menentukan bilangan terbesar dari dua bilangan bulat
# Masukkan bilangan pertama: 4
# Masukkan bilangan kedua: 8
# 8 terbesar
#
# ====================================================
#              Sudah Yakin??? (Ya atau Tidak)
# ====================================================
# Tidak
# Masukkan bilangan pertama: 9
# Masukkan bilangan kedua: 3
# 9 terbesar
#
# ====================================================
#              Sudah Yakin??? (Ya atau Tidak)
# ====================================================
# Ya
# Terima kasih, SEMANGAT:)

# %% [markdown]
# ## No 2

# %%
Pada akhir semester seorang dosen menghitung nilai akhir dari mahasiswa yang terdiri dari nilai uas, uts, kuis, dan tugas. Nilai akhir didapatkan dari 40% nilai uas, 30% nilai uts, 10% nilai kuis, dan 20% nilai tugas. Jika nilai akhir dari mahasiswa di bawah 65 maka mahasiswa tersebut akan mendapatkan remidi. Buatlah program untuk membantu mengetahui mahasiswa yang mendapatkan remidi berdasarkan nilai akhir yang didapatkannya!

# %%
### print ('menghitung nilai akhir mahasiswa')


def pengulangan():
    nama=input('Masukkan Nama Anda: ')
    nim=input('Masukkan NIM: ')
    smt=input('Masukkan Semester: ')
    matkul=input('Masukkan Mata Kuliah: ')
    tugas=float(input('Masukkan Nilai Tugas: '))
    kuis=float(input('Masukkan Nilai Kuis: '))
    uts=float(input('Masukkan Nilai UTS: '))
    uas=float(input('Masukkan Nilai UAS: '))

    nilaiakhir=(tugas*0.2)+(kuis*0.1)+(uts*0.3)+(uas*0.4)

    print('=============HASIL PERHITUNGAN=============')
    print('==============NILAI MAHASISWA==============')
    

    print('Nama :' ,nama)
    print('NIM :' ,nim)
    print('Smester :' ,smt)
    print('Mata Kuliah :' ,matkul)
    print('Nilai Tugas :' ,tugas)
    print('Nilai Kuis :' ,kuis)
    print('Nilai UTS :' ,uts)
    print('Nilai UAS :' ,uas)
    print('Nilai Akhir :' ,nilaiakhir)

    if nilaiakhir < 65:
        print('====MOHON MAAF, ANDA HARUS MENGIKUTI REMIDI====')
    else :
        print('====SELAMAT ANDA LULUS====')
        
    print('')
    print('====================================================')
    print('   APAKAH INGIN MENCOBA LAGI??? (Ya atau Tidak)    ')
    print('====================================================')
    x=input()
    if x=='Ya':
        return pengulangan()
    if x=='Tidak':
        print('Terima Kasih:)')
        
pengulangan()
# Out:
# Masukkan Nama Anda: Alif Fitri Auni Miftakhul Jannah
# Masukkan NIM: 222333
# Masukkan Semester: 1
# Masukkan Mata Kuliah: Sistem Dinamik
# Masukkan Nilai Tugas: 92
# Masukkan Nilai Kuis: 95
# Masukkan Nilai UTS: 97
# Masukkan Nilai UAS: 94
# =============HASIL PERHITUNGAN=============
# ==============NILAI MAHASISWA==============
# Nama : Alif Fitri Auni Miftakhul Jannah
# NIM : 222333
# Smester : 1
# Mata Kuliah : Sistem Dinamik
# Nilai Tugas : 92.0
# Nilai Kuis : 95.0
# Nilai UTS : 97.0
# Nilai UAS : 94.0
# Nilai Akhir : 94.6
# ====SELAMAT ANDA LULUS====
#
# ====================================================
#    APAKAH INGIN MENCOBA LAGI??? (Ya atau Tidak)
# ====================================================
# Ya
# Masukkan Nama Anda: Ukhti
# Masukkan NIM: 121212
# Masukkan Semester: 2
# Masukkan Mata Kuliah: Geometri
# Masukkan Nilai Tugas: 42
# Masukkan Nilai Kuis: 54
# Masukkan Nilai UTS: 45
# Masukkan Nilai UAS: 55
# =============HASIL PERHITUNGAN=============
# ==============NILAI MAHASISWA==============
# Nama : Ukhti
# NIM : 121212
# Smester : 2
# Mata Kuliah : Geometri
# Nilai Tugas : 42.0
# Nilai Kuis : 54.0
# Nilai UTS : 45.0
# Nilai UAS : 55.0
# Nilai Akhir : 49.3
# ====MOHON MAAF, ANDA HARUS MENGIKUTI REMIDI====
#
# ====================================================
#    APAKAH INGIN MENCOBA LAGI??? (Ya atau Tidak)
# ====================================================
# Tidak
# Terima Kasih:)

# %% [markdown]
# ## No 3

# %%
Buatlah program kalkulator sederhana menggunakan Python. User akan memasukkan dua buah bilangan riil dan satu buah operator aritmatika (+, -, *, atau /), kemudian program akan mengoperasikan dua bilangan tersebut dengan operator yang sesuai. Contoh tampilan program:

# %%
 print('Kalkulator Sederhana')
    
def pengulangan():
    #penjumlahan
    def add(x,y):
        return x+y
    #pengurangan
    def subtract(x,y):
        return x-y
    #perkalian
    def multiply(x,y):
        return x*y
    #pembagian
    def divide(x,y):
        return x/y

    print("Pilih Operasi: ")
    print("1.Penjumlahan")
    print("2.Pengurangan")
    print("3.Perkalian")
    print("4.Pembagian")

    pilih=input("Masukkan pilihan(1/2/3/4): ")
    a=float(input("Masukkan bilangan pertama: "))
    b=float(input("Masukkan bilangan kedua: "))
    if pilih == '1':
       print(a,"+",b,"=", add(a,b))
    elif pilih == '2':
       print(a,"-",b,"=", subtract(a,b))
    elif pilih == '3':
       print(a,"*",b,"=", multiply(a,b))
    elif pilih == '4':
       print(a,"/",b,"=", divide(a,b))
    else:
       print("Input salah")

    print ('')
    print ('====================================================')
    print ('             Ingin Mencoba Lagi??? (Ya atau Tidak)              ')
    print ('====================================================')
    x=input()
    if x=='Ya':
        return pengulangan()
    if x=='Tidak':
        print('Terima Kasih Telah Mencoba, GOOD LUCK!!!')
        
pengulangan()
# Out:
# Kalkulator Sederhana
# Pilih Operasi:
# 1.Penjumlahan
# 2.Pengurangan
# 3.Perkalian
# 4.Pembagian
# Masukkan pilihan(1/2/3/4): 2
# Masukkan bilangan pertama: 6
# Masukkan bilangan kedua: 5
# 6.0 - 5.0 = 1.0
#
# ====================================================
#              Ingin Mencoba Lagi??? (Ya atau Tidak)
# ====================================================
# Ya
# Pilih Operasi:
# 1.Penjumlahan
# 2.Pengurangan
# 3.Perkalian
# 4.Pembagian
# Masukkan pilihan(1/2/3/4): 3
# Masukkan bilangan pertama: 5
# Masukkan bilangan kedua: 5
# 5.0 * 5.0 = 25.0
#
# ====================================================
#              Ingin Mencoba Lagi??? (Ya atau Tidak)
# ====================================================
# Ya
# Pilih Operasi:
# 1.Penjumlahan
# 2.Pengurangan
# 3.Perkalian
# 4.Pembagian
# Masukkan pilihan(1/2/3/4): 1
# Masukkan bilangan pertama: 1
# Masukkan bilangan kedua: 2
# 1.0 + 2.0 = 3.0
#
# ====================================================
#              Ingin Mencoba Lagi??? (Ya atau Tidak)
# ====================================================
# Ya
# Pilih Operasi:
# 1.Penjumlahan
# 2.Pengurangan
# 3.Perkalian
# 4.Pembagian
# Masukkan pilihan(1/2/3/4): 4
# Masukkan bilangan pertama: 9
# Masukkan bilangan kedua: 2
# 9.0 / 2.0 = 4.5
#
# ====================================================
#              Ingin Mencoba Lagi??? (Ya atau Tidak)
# ====================================================
# Tidak
# Terima Kasih Telah Mencoba, GOOD LUCK!!!
